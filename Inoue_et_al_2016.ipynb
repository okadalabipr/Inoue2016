# %% [markdown]
# ### Simulation

# %%
include("runSim.jl");
sol = runSimulation();

# %% [markdown]
# ### Plot

# %%
include("plot.jl");
show();
# Out:
# Figure(PyObject <Figure size 1200x800 with 4 Axes>)
